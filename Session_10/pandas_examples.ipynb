# %%
# pip install pandas

# %%
import pandas as pd

# %%
s = pd.Series(data=[1,2,3], index=['a', 'b','c'])
s
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
s = pd.Series(data=[1,2,3], index=['a', 'b','c'], dtype=float)
s
# Out:
# a    1.0
# b    2.0
# c    3.0
# dtype: float64

# %% [markdown]
# #### Data
# ![image.png](attachment:e86d2a88-e32d-4db0-bdec-08a0359b14bd.png)

# %%
data = {
    'city': ['Dublin', 'Palo Alto', 'Fremont'],
    'state': ['CA','CA','CA'],
    'median_home_price_in_million': [1.5, 2, 1.7]
}
data
# Out:
# {'city': ['Dublin', 'Palo Alto', 'Fremont'],
#  'state': ['CA', 'CA', 'CA'],
#  'median_home_price_in_million': [1.5, 2, 1.7]}

# %%
dataframe = pd.DataFrame(data)
dataframe
# Out:
#         city state  median_home_price_in_million
# 0     Dublin    CA                           1.5
# 1  Palo Alto    CA                           2.0
# 2    Fremont    CA                           1.7

# %%
print (dataframe)
# Out:
#         city state  median_home_price_in_million
# 0     Dublin    CA                           1.5
# 1  Palo Alto    CA                           2.0
# 2    Fremont    CA                           1.7

# %% [markdown]
# ### Reading Data

# %%
df = pd.read_csv('data/housing_data.csv')
df
# Out:
#         city state  price
# 0     Dublin    CA    1.5
# 1  Palo Alto    CA    2.0
# 2    Fremont    CA    1.7

# %%
df.head()
# Out:
#         city state  price
# 0     Dublin    CA    1.5
# 1  Palo Alto    CA    2.0
# 2    Fremont    CA    1.7

# %%
df.head(10)
# Out:
#         city state  price
# 0     Dublin    CA    1.5
# 1  Palo Alto    CA    2.0
# 2    Fremont    CA    1.7

# %%
df.tail()
# Out:
#         city state  price
# 0     Dublin    CA    1.5
# 1  Palo Alto    CA    2.0
# 2    Fremont    CA    1.7

# %%
df.tail(3)
# Out:
#         city state  price
# 0     Dublin    CA    1.5
# 1  Palo Alto    CA    2.0
# 2    Fremont    CA    1.7

# %%
df_from_json = pd.read_json('data/housing_data2.json')
df_from_json
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df_from_json = pd.read_json('data/housing_data2.json')
#       2 df_from_json
#
# File ~/sansa/.venv/lib/python3.13/site-packages/pandas/io/json/_json.py:791, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     788 if convert_axes is None and orient != "table":
#     789     convert_axes = True
# --> 791 json_reader = JsonReader(
#     792     path_or_buf,
#     793     orient=orient,
#     794     typ=typ,
#     795     dtype=dtype,
#     796     convert_axes=convert_axes,
#     797     convert_dates=convert_dates,
#     798     keep_default_dates=keep_default_dates,
#     799     precise_float=precise_float,
#     800     date_unit=date_unit,
#     801     encoding=encoding,
#     802     lines=lines,
#     803     chunksize=chunksize,
#     804     compression=compression,
#     805     nrows=nrows,
#     806     storage_options=storage_options,
#     807     encoding_errors=encoding_errors,
#     808     dtype_backend=dtype_backend,
#     809     engine=engine,
#     810 )
#     812 if chunksize:
#     813     return json_reader
#
# File ~/sansa/.venv/lib/python3.13/site-packages/pandas/io/json/_json.py:904, in JsonReader.__init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors, dtype_backend, engine)
#     902     self.data = filepath_or_buffer
#     903 elif self.engine == "ujson":
# --> 904     data = self._get_data_from_filepath(filepath_or_buffer)
#     905     self.data = self._preprocess_data(data)
#
# File ~/sansa/.venv/lib/python3.13/site-packages/pandas/io/json/_json.py:960, in JsonReader._get_data_from_filepath(self, filepath_or_buffer)
#     952     filepath_or_buffer = self.handles.handle
#     953 elif (
#     954     isinstance(filepath_or_buffer, str)
#     955     and filepath_or_buffer.lower().endswith(
#    (...)    958     and not file_exists(filepath_or_buffer)
#     959 ):
# --> 960     raise FileNotFoundError(f"File {filepath_or_buffer} does not exist")
#     961 else:
#     962     warnings.warn(
#     963         "Passing literal json to 'read_json' is deprecated and "
#     964         "will be removed in a future version. To read from a "
#    (...)    967         stacklevel=find_stack_level(),
#     968     )
#
# FileNotFoundError: File data/housing_data2.json does not exist

# %% [markdown]
# ### Writing to a data file

# %%
df_from_json.to_csv('data/out_data1.csv', mode = 'w')

# %%
df_from_json.to_csv('data/out_data2.csv', mode = 'w', index=False)

# %%
df_from_json.to_json('data/out_data3.json', orient='records')

# %% [markdown]
# ### Explore Data

# %%
data = pd.read_csv("data/housing_data.csv")
data
# Out:
#         city state  price
# 0     Dublin    CA    1.5
# 1  Palo Alto    CA    2.0
# 2    Fremont    CA    1.7

# %%
data.head()
# Out:
#         city state  price
# 0     Dublin    CA    1.5
# 1  Palo Alto    CA    2.0
# 2    Fremont    CA    1.7

# %%
data.head(1)
# Out:
#      city state  price
# 0  Dublin    CA    1.5

# %%
data.tail()
# Out:
#         city state  price
# 0     Dublin    CA    1.5
# 1  Palo Alto    CA    2.0
# 2    Fremont    CA    1.7

# %%
data.tail(7)
# Out:
#           city state  median_home_price_in_million
# 13     Hayward    CA                           1.1
# 14  Union City    NH                           1.3
# 15     Concord    NH                           0.5
# 16   Merrimack    NH                           0.7
# 17   San Mateo    CA                           2.2
# 18   Los Altos    CA                           3.0
# 19    Campbell    CA                           1.7

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   city    3 non-null      object
#  1   state   3 non-null      object
#  2   price   3 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 204.0+ bytes

# %%
data.describe()
# Out:
#           price
# count  3.000000
# mean   1.733333
# std    0.251661
# min    1.500000
# 25%    1.600000
# 50%    1.700000
# 75%    1.850000
# max    2.000000

# %%
data['city'].value_counts()
# Out:
# city
# Dublin       1
# Palo Alto    1
# Fremont      1
# Name: count, dtype: int64

# %%
data[['city']]
# Out:
#         city
# 0     Dublin
# 1  Palo Alto
# 2    Fremont

# %%
data[['city', 'state']].value_counts()
# Out:
# city       state
# Dublin     CA       1
# Fremont    CA       1
# Palo Alto  CA       1
# Name: count, dtype: int64

# %%
type(data['city'])
# Out:
# pandas.core.series.Series

# %%
data['city'].value_counts()
# Out:
# city
# Dublin       1
# Palo Alto    1
# Fremont      1
# Name: count, dtype: int64

# %%
X_features = data[['city', 'state']]
y_label = data['price']

# %%
X_features.head()
# Out:
#         city state
# 0     Dublin    CA
# 1  Palo Alto    CA
# 2    Fremont    CA

# %%
y_label.head()
# Out:
# 0    1.5
# 1    2.0
# 2    1.7
# Name: price, dtype: float64

# %% [markdown]
# ### Indexing, Selecting, and Filtering

# %%
# Column selection
data['price'], type(data['price'])
# Out:
# (0    1.5
#  1    2.0
#  2    1.7
#  Name: price, dtype: float64,
#  pandas.core.series.Series)

# %%
# Multiple Columns selection
data[['city', 'state']], type(data[['city', 'state']])
# Out:
# (        city state
#  0     Dublin    CA
#  1  Palo Alto    CA
#  2    Fremont    CA,
#  pandas.core.frame.DataFrame)

# %%
# Row selection
# by position
data.iloc[2], type(data.iloc[2])
# Out:
# (city     Fremont
#  state         CA
#  price        1.7
#  Name: 2, dtype: object,
#  pandas.core.series.Series)

# %%
data.head()
# Out:
#         city state  price
# 0     Dublin    CA    1.5
# 1  Palo Alto    CA    2.0
# 2    Fremont    CA    1.7

# %%
# by label (if index is labeled)
data.loc[0]
# Out:
# city     Dublin
# state        CA
# price       1.5
# Name: 0, dtype: object

# %% [markdown]
# ## Data Cleaning

# %%
# Checking for missing values
data.isna().sum()
# Out:
# city     0
# state    0
# price    0
# dtype: int64

# %%
# Fill missing values
data.fillna(0, inplace=True)
data.isna().sum()
# Out:
# city     0
# state    0
# price    0
# dtype: int64

# %%
# Drop missing
data.dropna(inplace=True)

# %%
# Rename columns
data.rename(columns={'city':'CITY'}, inplace=True )
data.columns
# Out:
# Index(['CITY', 'state', 'price'], dtype='object')

# %%
# Replace values
data.replace({'CA':'NH'}, inplace=True)
data
# Out:
#         CITY state  price
# 0     Dublin    NH    1.5
# 1  Palo Alto    NH    2.0
# 2    Fremont    NH    1.7

# %%
data.replace({'NH':'CA'})
data2 = data.replace({'NH':'AZ'})
data, data2
# Out:
# (        CITY state  price
#  0     Dublin    NH    1.5
#  1  Palo Alto    NH    2.0
#  2    Fremont    NH    1.7,
#          CITY state  price
#  0     Dublin    AZ    1.5
#  1  Palo Alto    AZ    2.0
#  2    Fremont    AZ    1.7)

# %%
data.replace({'NH': 'CA'}, inplace=True)
data.head()
# Out:
#         CITY state  price
# 0     Dublin    CA    1.5
# 1  Palo Alto    CA    2.0
# 2    Fremont    CA    1.7

# %% [markdown]
# #### Grouping & Aggregation

# %%
data = pd.read_csv('data/housing_data.csv')
data.head()
# Out:
#         city state  price
# 0     Dublin    CA    1.5
# 1  Palo Alto    CA    2.0
# 2    Fremont    CA    1.7

# %%
data.groupby('state')['price'].mean(), data.groupby('state')['price'].median()
# Out:
# (state
#  CA    1.733333
#  Name: price, dtype: float64,
#  state
#  CA    1.7
#  Name: price, dtype: float64)

# %%
data.groupby('state').agg(
    {
    'price': ['mean', 'median', 'max', 'min']
    })
# Out:
#           price
#            mean median  max  min
# state
# CA     1.733333    1.7  2.0  1.5

# %%
data.describe()
# Out:
#           price
# count  3.000000
# mean   1.733333
# std    0.251661
# min    1.500000
# 25%    1.600000
# 50%    1.700000
# 75%    1.850000
# max    2.000000

# %% [markdown]
# #### Merging and Joining Data

# %%
df1 = pd.DataFrame({'capital':['Paris','New Delhi', 'Washington DC'], \
                    'country':['France', 'India', 'United States of America']})
df1
# Out:
#          capital                   country
# 0          Paris                    France
# 1      New Delhi                     India
# 2  Washington DC  United States of America

# %%
df2 = pd.DataFrame({'capital':['Paris','New Delhi', 'Washington DC'], 
                    'country_iso_code':['FR', 'IN', 'US']})
df2
# Out:
#          capital country_iso_code
# 0          Paris               FR
# 1      New Delhi               IN
# 2  Washington DC               US

# %%
df_merged = pd.merge(df1, df2, on='capital')
df_merged
# Out:
#          capital                   country country_iso_code
# 0          Paris                    France               FR
# 1      New Delhi                     India               IN
# 2  Washington DC  United States of America               US

# %%
df_combined = pd.concat([df1, df2], axis = 1)
df_combined
# Out:
#          capital                   country        capital country_iso_code
# 0          Paris                    France          Paris               FR
# 1      New Delhi                     India      New Delhi               IN
# 2  Washington DC  United States of America  Washington DC               US
